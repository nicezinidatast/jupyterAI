# %%
import os
import plotly
import sqlalchemy
print("plotly",plotly.__version__,"sqlalchemy",sqlalchemy.__version__)
# Out:
# plotly 5.24.1 sqlalchemy 2.0.36

# %%
print("engines:", "sales_engine" in dir(), "crm_engine" in dir())
print(sales_engine, crm_engine)
# Out:
# engines: True True
# Engine(postgresql+psycopg2://demo:***@demo-postgres:5432/sales) Engine(mysql+pymysql://demo:***@demo-mysql:3306/crm)

# %%
# %%sql
# SELECT COUNT(*) AS n FROM sales.customers
# Out:
#       n
# 0  1500

# %%
# %sql crm_engine

# %%
# %%sql
# SELECT COUNT(*) AS n FROM leads
# Out:
#       n
# 0  1500

# %%
import pandas as pd
df = pd.read_sql("SELECT name, city FROM sales.customers LIMIT 5", sales_engine)
print(df.shape); print(df.head())
# Out:
# (5, 2)
#              name     city
# 0    Kim Ji-soo 1    Busan
# 1  Lee Seo-yeon 2  Incheon
# 2  Choi Eun-woo 3    Daegu
# 3  Jung Ha-yoon 4  Daejeon
# 4  Kang Do-yoon 5  Gwangju

# %%
import plotly.express as px
fig = px.bar(df, x="city", y=df.index, title="smoke")
print(type(fig).__name__)
# Out:
# Figure
